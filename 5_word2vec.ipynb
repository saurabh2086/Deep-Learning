# %% [markdown]
# # Deep Learning

# %% [markdown]
# ## Assignment 5
# The goal of this assignment is to train a Word2Vec skip-gram model over Text8 data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /Users/saurabh/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
        statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
          'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000
def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary
data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'anarchism', 'originated', 'a', 'of', 'as', 'originated', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default(), tf.device('/cpu:0'):
    train_dataset = tf.placeholder(tf.int32, [batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size,1])
    valid_dataset = tf.constant(valid_examples,dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size,embedding_size],-1.0,1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size,embedding_size],stddev= 1.0/math.sqrt(embedding_size)))
    
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    embed = tf.tf.nn.embedding_lookup(embeddings,train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(
            softmax_weights,softmax_biases,embed,train_labels,num_sampled,vocabulary_size))
    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.021762
# Nearest to most: corrino, hermeneutic, yearwood, norman, erupt, amphetamines, counted, sasson,
# Nearest to between: domains, malenkov, mandrakesoft, konkan, scan, nominalism, characterised, cognate,
# Nearest to nine: marat, servers, diaspora, shields, horse, yards, endeavor, ting,
# Nearest to no: borgir, thrace, aerobic, feudalism, ufos, maine, rarities, trimester,
# Nearest to so: hydrologic, merkle, static, levitt, trouser, bothnia, reflexes, fr,
# Nearest to b: antiderivative, accountancy, carmelites, mustaine, appreciated, potato, veronica, trianon,
# Nearest to called: lessens, standardizing, allophones, minute, losers, hereford, coexistence, family,
# Nearest to from: spectra, regnum, gulliver, intermixed, vall, satellite, oneness, unfettered,
# Nearest to his: bound, bolts, merril, fascinated, appalled, sideband, advancing, ekaterina,
# Nearest to have: defensive, kia, awk, tight, consolidated, capoeiristas, himself, valuation,
# Nearest to four: layoffs, laia, ur, atoms, rlc, libyans, precincts, guillotine,
# Nearest to of: whittaker, jagan, alec, tear, nugent, az, plurals, predictably,
# Nearest to not: hausdorff, abdallah, forgetfulness, importation, inheritance, artemisia, gorgias, cassian,
# Nearest to th: foundationalism, frequentist, fracturing, withholding, priscilla, chairperson, xaver, viceroy,
# Nearest to by: coursework, sociale, suffragette, petsamo, anglican, hastings, minimalist, grander,
# Nearest to about: disenfranchisement, exclusive, condon, kaf, cons, shoulder, shrimp, litani,
# Average loss at step 2000: 4.362272
# Average loss at step 4000: 3.868478
# Average loss at step 6000: 3.791864
# Average loss at step 8000: 3.686648
# Average loss at step 10000: 3.613351
# Nearest to most: some, all, hermeneutic, alliance, hummer, falconiformes, travolta, amphetamines,
# Nearest to between: with, malenkov, in, scan, cognate, mandrakesoft, martha, aerodynamic,
# Nearest to nine: eight, six, zero, five, seven, four, three, two,
# Nearest to no: borgir, aerobic, they, thrace, given, erbium, clusters, we,
# Nearest to so: thus, replies, hydrologic, minions, fr, bothnia, combating, vacated,
# Nearest to b: d, antiderivative, accountancy, botc, micrograms, potato, repatriation, mustaine,
# Nearest to called: losers, allophones, saved, anh, tide, lessens, receiving, hereford,
# Nearest to from: in, at, by, kilometres, grind, mug, cornerstone, with,
# Nearest to his: their, its, her, the, s, heretofore, motocross, instinctively,
# Nearest to have: has, had, are, be, javelin, tight, favre, customary,
# Nearest to four: eight, six, three, five, seven, two, nine, zero,
# Nearest to of: in, for, at, satellites, collectivity, and, whittaker, s,
# Nearest to not: often, it, they, to, there, grierson, he, historians,
# Nearest to th: foundationalism, priscilla, withholding, councillor, larva, sevilla, manslaughter, viceroy,
# Nearest to by: was, in, on, norepinephrine, with, from, johannine, anglican,
# Nearest to about: cylinder, melanogaster, shrimp, radicals, condon, disenfranchisement, cons, savile,
# Average loss at step 12000: 3.605648
# Average loss at step 14000: 3.571648
# Average loss at step 16000: 3.405887
# Average loss at step 18000: 3.456123
# Average loss at step 20000: 3.537548
# Nearest to most: some, hermeneutic, more, alternate, all, hummer, nostrils, many,
# Nearest to between: with, malenkov, in, scan, mandrakesoft, among, cognate, around,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to no: borgir, still, there, earthquake, any, a, we, slows,
# Nearest to so: vacated, replies, thus, minions, hydrologic, fr, bothnia, overlapping,
# Nearest to b: d, spectacularly, repatriation, inhibition, green, extinguisher, spanish, germline,
# Nearest to called: losers, iranian, saved, anh, leno, crossing, evicted, minuscule,
# Nearest to from: in, into, kilometres, at, kun, mug, with, and,
# Nearest to his: their, her, its, the, heretofore, instinctively, matti, refuting,
# Nearest to have: had, has, be, were, are, hbo, javelin, favre,
# Nearest to four: three, six, eight, five, seven, nine, two, zero,
# Nearest to of: second, original, peruvian, jagan, for, herc, damascus, uno,
# Nearest to not: often, to, they, it, now, gorgias, grierson, also,
# Nearest to th: priscilla, viceroy, bohm, foundationalism, councillor, withholding, plebeians, sibley,
# Nearest to by: into, with, were, souvenir, johannine, being, be, been,
# Nearest to about: cylinder, nameserver, condon, radicals, melanogaster, quarterly, shrimp, follett,
# Average loss at step 22000: 3.500632
# Average loss at step 24000: 3.489877
# Average loss at step 26000: 3.476863
# Average loss at step 28000: 3.477684
# Average loss at step 30000: 3.506037
# Nearest to most: more, some, hermeneutic, vern, all, falconiformes, hummer, many,
# Nearest to between: with, malenkov, in, scan, among, aerodynamic, mandrakesoft, teletext,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to no: any, still, borgir, slows, there, a, we, slanted,
# Nearest to so: thus, vacated, replies, minions, hydrologic, fleischer, argue, then,
# Nearest to b: d, germline, l, inhibition, appropriations, extinguisher, fatally, importation,
# Nearest to called: losers, anh, crossing, asymmetrical, used, telford, acetylene, amygdalin,
# Nearest to from: into, in, mug, and, by, branded, of, after,
# Nearest to his: her, their, the, its, s, a, heretofore, antony,
# Nearest to have: had, has, be, were, are, having, quarto, javelin,
# Nearest to four: eight, five, six, seven, three, nine, two, zero,
# Nearest to of: in, peruvian, and, for, indic, including, initial, from,
# Nearest to not: they, often, it, still, there, never, grierson, faintly,
# Nearest to th: logicians, plebeians, viceroy, one, prudent, councillor, priscilla, bohm,
# Nearest to by: in, with, from, were, johannine, aerobatics, lad, was,
# Nearest to about: cylinder, nameserver, savile, shouldn, shapiro, cassation, reserves, condon,
# Average loss at step 32000: 3.502198
# Average loss at step 34000: 3.491586
# Average loss at step 36000: 3.456252
# Average loss at step 38000: 3.305045
# Average loss at step 40000: 3.426200
# Nearest to most: more, less, some, many, vern, hermeneutic, managerial, all,
# Nearest to between: with, malenkov, scan, around, among, repeaters, mandrakesoft, aerodynamic,
# Nearest to nine: eight, seven, six, five, four, zero, three, two,
# Nearest to no: any, receptors, still, phosphorylation, slows, slanted, there, it,
# Nearest to so: thus, vacated, replies, argue, visigoth, compliance, fleischer, pulsars,
# Nearest to b: d, UNK, germline, l, serbians, fingertips, accountancy, roll,
# Nearest to called: losers, telford, amygdalin, used, anh, bled, convoluted, asymmetrical,
# Nearest to from: into, through, mug, kilometres, sprites, gbu, in, branded,
# Nearest to his: her, their, its, s, the, your, my, grenades,
# Nearest to have: had, has, be, were, are, dmd, quarto, withstood,
# Nearest to four: six, seven, three, five, eight, two, nine, one,
# Nearest to of: peruvian, in, collectivity, incontinence, for, initial, futurians, frigg,
# Nearest to not: often, they, it, still, now, never, you, usually,
# Nearest to th: prudent, plebeians, logicians, sibley, heraclius, bohm, experimentation, zero,
# Nearest to by: with, be, wissowa, rium, for, coursework, johannine, interacted,
# Nearest to about: cassation, savile, condon, on, certificates, owsley, tattooing, cons,
# Average loss at step 42000: 3.432784
# Average loss at step 44000: 3.451417
# Average loss at step 46000: 3.446895
# Average loss at step 48000: 3.354985
# Average loss at step 50000: 3.378751
# Nearest to most: more, less, many, some, vern, advertise, offical, dahmer,
# Nearest to between: with, malenkov, scan, among, around, repeaters, aerodynamic, teletext,
# Nearest to nine: eight, six, seven, four, three, five, zero, two,
# Nearest to no: any, phosphorylation, receptors, little, a, alonso, quartering, slots,
# Nearest to so: thus, vacated, replies, then, however, visigoth, he, hawaii,
# Nearest to b: d, serbians, transvestite, heal, r, germline, tutoring, benoit,
# Nearest to called: losers, amygdalin, named, known, bled, used, geometer, asymmetrical,
# Nearest to from: into, through, in, mug, at, after, under, gbu,
# Nearest to his: her, their, its, my, the, our, instinctively, s,
# Nearest to have: had, has, were, are, be, having, refer, get,
# Nearest to four: six, five, seven, eight, three, nine, two, zero,
# Nearest to of: in, and, flatly, peruvian, initial, including, personhood, femininity,
# Nearest to not: never, now, they, often, generally, always, it, who,
# Nearest to th: six, prudent, bce, heraclius, sibley, four, one, plebeians,
# Nearest to by: was, lad, toward, with, johannine, fantastic, be, arch,
# Nearest to about: cassation, tattooing, condon, savile, certificates, piano, precious, on,
# Average loss at step 52000: 3.439279
# Average loss at step 54000: 3.424826
# Average loss at step 56000: 3.437332
# Average loss at step 58000: 3.394218
# Average loss at step 60000: 3.392119
# Nearest to most: more, less, many, some, isaias, managerial, vern, maratha,
# Nearest to between: with, among, in, scan, malenkov, edda, repeaters, aerodynamic,
# Nearest to nine: eight, six, seven, five, four, three, zero, one,
# Nearest to no: any, receptors, phosphorylation, little, hog, pictured, a, alonso,
# Nearest to so: thus, replies, vacated, then, rebuttal, hawaii, visigoth, faster,
# Nearest to b: d, c, f, r, heal, m, p, k,
# Nearest to called: used, named, amygdalin, known, losers, acetylene, bled, geometer,
# Nearest to from: into, through, exorbitant, in, branded, compactification, marrying, predictability,
# Nearest to his: her, their, its, my, the, our, instinctively, your,
# Nearest to have: had, has, are, were, having, be, include, refer,
# Nearest to four: five, six, three, eight, seven, nine, zero, two,
# Nearest to of: in, personhood, for, femininity, same, initial, reichstag, although,
# Nearest to not: never, still, now, they, usually, generally, faintly, often,
# Nearest to th: zero, bce, eight, heraclius, five, six, plebeians, ad,
# Nearest to by: with, lad, dart, dominic, was, while, through, be,
# Nearest to about: radicals, cassation, condon, savile, coke, on, precious, tattooing,
# Average loss at step 62000: 3.242948
# Average loss at step 64000: 3.252628
# Average loss at step 66000: 3.401137
# Average loss at step 68000: 3.393367
# Average loss at step 70000: 3.359685
# Nearest to most: more, less, many, some, dahmer, all, vern, very,
# Nearest to between: among, with, repeaters, in, scan, edda, within, zander,
# Nearest to nine: eight, six, seven, five, four, three, zero, two,
# Nearest to no: any, receptors, little, hog, still, phosphorylation, alonso, there,
# Nearest to so: thus, replies, hawaii, rebuttal, then, vacated, faster, chisholm,
# Nearest to b: d, f, r, handwritten, heal, p, germline, serbians,
# Nearest to called: named, amygdalin, known, referred, used, bled, sequencing, considered,
# Nearest to from: through, into, under, in, branded, via, mug, by,
# Nearest to his: her, their, its, my, our, your, instinctively, the,
# Nearest to have: had, has, are, were, be, having, require, suggest,
# Nearest to four: five, six, seven, three, eight, two, nine, zero,
# Nearest to of: including, and, initial, include, collectivity, in, wpan, original,
# Nearest to not: now, still, never, generally, faintly, often, they, always,
# Nearest to th: bce, heraclius, sibley, ad, bc, prudent, logicians, plebeians,
# Nearest to by: through, be, was, in, wissowa, being, cauca, from,
# Nearest to about: savile, radicals, karzai, tattooing, frequent, over, cassation, certificates,
# Average loss at step 72000: 3.367909
# Average loss at step 74000: 3.348333
# Average loss at step 76000: 3.309944
# Average loss at step 78000: 3.357203
# Average loss at step 80000: 3.379412
# Nearest to most: less, more, many, some, hypothetical, mirrors, dahmer, resumed,
# Nearest to between: among, with, within, repeaters, around, scan, in, from,
# Nearest to nine: eight, seven, six, five, four, three, zero, two,
# Nearest to no: little, any, hog, alonso, receptors, phosphorylation, persuasive, renounces,
# Nearest to so: thus, rebuttal, replies, hawaii, then, faster, if, visigoth,
# Nearest to b: d, f, c, handwritten, r, germline, m, touchdowns,
# Nearest to called: named, known, used, amygdalin, referred, bled, sequencing, considered,
# Nearest to from: through, into, under, mug, between, across, in, by,
# Nearest to his: her, their, my, its, your, our, personal, grenades,
# Nearest to have: had, has, be, having, are, were, require, suggest,
# Nearest to four: five, six, three, eight, seven, two, nine, zero,
# Nearest to of: indic, initial, including, in, previous, ado, original, peruvian,
# Nearest to not: still, now, never, often, generally, always, usually, faintly,
# Nearest to th: bce, heraclius, sibley, ad, prudent, rd, third, bc,
# Nearest to by: lad, from, with, through, crawford, when, was, wright,
# Nearest to about: savile, over, roughly, tattooing, karzai, cassation, orang, piano,
# Average loss at step 82000: 3.409127
# Average loss at step 84000: 3.408400
# Average loss at step 86000: 3.385600
# Average loss at step 88000: 3.352726
# Average loss at step 90000: 3.364799
# Nearest to most: more, less, many, some, several, dahmer, hypothetical, among,
# Nearest to between: among, within, with, around, scan, from, malenkov, repeaters,
# Nearest to nine: eight, seven, six, five, four, three, two, zero,
# Nearest to no: any, little, only, persuasive, receptors, phosphorylation, hog, now,
# Nearest to so: thus, rebuttal, if, replies, circuitry, vacated, then, hawaii,
# Nearest to b: d, f, r, handwritten, c, m, germline, l,
# Nearest to called: named, referred, used, considered, known, sequencing, amygdalin, omnipresent,
# Nearest to from: through, into, under, despite, during, via, mug, between,
# Nearest to his: her, their, its, my, your, our, the, s,
# Nearest to have: had, has, were, having, be, are, include, require,
# Nearest to four: six, seven, five, eight, three, two, nine, one,
# Nearest to of: including, initial, principal, whittaker, for, following, indic, in,
# Nearest to not: still, now, never, generally, always, nmi, often, we,
# Nearest to th: bce, one, ad, sibley, rd, heraclius, prudent, second,
# Nearest to by: through, with, lad, when, extinguished, was, for, while,
# Nearest to about: savile, over, karzai, tattooing, condon, regarding, cassation, microvision,
# Average loss at step 92000: 3.398455
# Average loss at step 94000: 3.251492
# Average loss at step 96000: 3.360246
# Average loss at step 98000: 3.242786
# Average loss at step 100000: 3.354653
# Nearest to most: more, less, especially, many, particularly, among, some, dahmer,
# Nearest to between: with, among, repeaters, within, around, scan, malenkov, aerodynamic,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to no: any, little, receptors, persuasive, there, phosphorylation, only, unclear,
# Nearest to so: thus, then, if, rebuttal, vacated, when, circuitry, cdf,
# Nearest to b: d, benoit, inhibition, rev, germline, handwritten, gia, f,
# Nearest to called: named, referred, used, bled, termed, known, considered, amygdalin,
# Nearest to from: into, in, through, via, branded, heels, exorbitant, at,
# Nearest to his: her, their, my, your, its, the, our, s,
# Nearest to have: had, has, require, were, be, are, having, include,
# Nearest to four: six, seven, five, eight, three, two, zero, nine,
# Nearest to of: in, including, and, indic, aino, instill, molyneux, cenozoic,
# Nearest to not: never, now, still, generally, faintly, nmi, only, always,
# Nearest to th: rd, one, bce, heraclius, fifth, sibley, second, third,
# Nearest to by: through, lad, when, errands, newly, during, visa, dominic,
# Nearest to about: savile, over, regarding, deaths, tattooing, cassation, condon, roughly,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# # Problem
# An alternative to skip-gram is another Word2Vec model called CBOW (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.

# %% [markdown]
# # Lets do CBOW model

# %% [markdown]
# CBOW is different in sence the if you have a text like
#
# `the quick brown fox jumped over the lazy dog`
#
# then the CBOW representation of this would be for window size 1
#
# `([the, brown], quick), ([quick, fox], brown), ([brown, jumped], fox), ...`

# %%
from itertools import compress
def generate_batch_cbow(data, batch_size, num_skips, skip_window):
    '''
    Batch generator for CBOW (Continuous Bag of Words).
    batch should be a shape of (batch_size, num_skips)
    Parameters
    ----------
    data: list of index of words
    batch_size: number of words in each mini-batch
    num_skips: number of surrounding words on both direction (2: one word ahead and one word following)
    skip_window: number of words at both ends of a sentence to skip (1: skip the first and last word of a sentence)
    '''
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size, num_skips), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span) # used for collecting data[data_index] in the sliding window
    # collect the first window of words
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # move the sliding window  
    for i in range(batch_size):
        mask = [1] * span
        mask[skip_window] = 0 
        batch[i, :] = list(compress(buffer, mask)) # all surrounding words
        labels[i, 0] = buffer[skip_window] # the word at the center 
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch_cbow( data[:8],batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    if num_skips == 2 and skip_window == 1:
        print('    data:',[reverse_dictionary[i] + ", " + reverse_dictionary[j] for i,j in batch.tolist()])
        print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     data: ['anarchism, as', 'originated, a', 'as, term', 'a, of', 'term, abuse', 'of, first', 'abuse, anarchism', 'first, originated']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'anarchism']
#
# with num_skips = 4 and skip_window = 2:

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default(), tf.device('/cpu:0'):
    train_dataset = tf.placeholder(tf.int32, [batch_size,num_skips])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size,1])
    valid_dataset = tf.constant(valid_examples,dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size,embedding_size],-1.0,1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size,embedding_size],stddev= 1.0/math.sqrt(embedding_size)))
    
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    embed = tf.reduce_sum(tf.nn.embedding_lookup(embeddings,train_dataset),1)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(
            softmax_weights,softmax_biases,embed,train_labels,num_sampled,vocabulary_size))
    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      data, batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.657054
# Nearest to b: stouffer, repression, cyaxares, tramiel, gadgets, cordite, lansana, annotated,
# Nearest to with: sid, pok, sharon, valerian, sdk, equine, vermont, abbey,
# Nearest to only: methodological, genome, android, quayle, xing, negotiators, jaspers, tsui,
# Nearest to were: athletics, godf, aliyah, incur, shoot, deconvolution, shinto, bible,
# Nearest to years: fergus, chimes, semitone, destabilization, rhazes, busiest, massing, mangrove,
# Nearest to there: fpgas, sponsor, moderator, saskatoon, inferno, duties, ipod, kazakh,
# Nearest to an: tenures, prime, meritorious, pepper, monkees, ipod, occam, sense,
# Nearest to the: tice, gunshot, piso, baffin, furnace, oracle, spreadsheet, marijuana,
# Nearest to when: lycanthropy, overran, complain, superpowers, wendish, helpful, panics, alcohols,
# Nearest to world: selden, failing, coalescence, lets, confess, priam, statisticians, readily,
# Nearest to war: iii, sunk, caller, compromising, maser, who, republicans, verdicts,
# Nearest to new: waging, siouxsie, tyres, emigr, ritter, hawkwind, stays, steamers,
# Nearest to at: mordant, comfort, nickname, tam, breathed, malagasy, sank, trance,
# Nearest to which: storehouses, closing, dictatorial, rawlings, taxi, stench, strut, wrestlemania,
# Nearest to six: listening, juries, coordination, weavers, rsc, cartels, nuanced, kochi,
# Nearest to many: courtly, esteem, cherubim, artistic, desirable, hermas, initialism, shredded,
# Average loss at step 2000: 4.065277
# Average loss at step 4000: 3.474607
# Average loss at step 6000: 3.337709
# Average loss at step 8000: 3.319037
# Average loss at step 10000: 3.261968
# Nearest to b: d, hour, marshy, stoneman, edda, farm, unleashing, momenta,
# Nearest to with: between, equine, by, rightist, in, at, and, genetical,
# Nearest to only: promiscuous, germ, fenwick, filter, generally, mandrakesoft, acquire, abbots,
# Nearest to were: are, was, have, had, iceberg, benin, be, demonym,
# Nearest to years: year, restaurants, extent, consumers, period, elementary, maison, trains,
# Nearest to there: they, it, which, he, fpgas, these, beacon, distributist,
# Nearest to an: dyslexic, waxes, lebrun, subsumed, ninlil, determined, sex, colouring,
# Nearest to the: its, his, their, this, a, cy, gus, bcpl,
# Nearest to when: where, deceptive, if, stiller, yehuda, schiff, typewriters, syntactical,
# Nearest to world: coalescence, cusp, werewolves, needs, next, confess, eugenicists, instructing,
# Nearest to war: physica, fifa, iii, sunk, rockets, reincorporated, compromising, maser,
# Nearest to new: particular, psalms, gothenburg, minotaurs, racers, talib, glace, waging,
# Nearest to at: in, kicked, misheard, hessen, with, forefront, lgbt, on,
# Nearest to which: that, this, it, also, there, who, midtown, traversing,
# Nearest to six: four, seven, eight, five, nine, zero, three, two,
# Nearest to many: some, several, all, lehmann, other, mentor, cow, hing,
# Average loss at step 12000: 3.254979
# Average loss at step 14000: 3.196161
# Average loss at step 16000: 3.064657
# Average loss at step 18000: 3.120010
# Average loss at step 20000: 3.099252
# Nearest to b: d, normand, momenta, vase, c, farm, mesopotamian, avalokitesvara,
# Nearest to with: between, by, freitas, risky, equine, in, when, leontopithecus,
# Nearest to only: promiscuous, poorly, chicxulub, mandrakesoft, fenwick, all, generally, vancouver,
# Nearest to were: are, have, was, had, be, snack, yemen, lepidoptera,
# Nearest to years: year, months, days, decades, norm, restaurants, times, venturing,
# Nearest to there: they, it, he, often, usually, bonzos, now, snapper,
# Nearest to an: waxes, dyslexic, subsumed, liters, erosion, painters, ct, catamaran,
# Nearest to the: their, his, its, some, this, macho, these, herring,
# Nearest to when: if, where, while, after, before, though, during, as,
# Nearest to world: coalescence, werewolves, lions, failing, confess, civil, pacified, vendors,
# Nearest to war: physica, fifa, francesca, propagandist, infinitive, vapors, inspirational, fournier,
# Nearest to new: particular, review, psalms, waging, gothenburg, gyula, racers, reinstating,
# Nearest to at: in, on, astrologers, hessen, meme, gruyter, from, gorge,
# Nearest to which: that, this, who, also, what, mustard, candidacy, it,
# Nearest to six: four, five, eight, seven, nine, three, zero, two,
# Nearest to many: some, several, these, various, lehmann, all, those, most,
# Average loss at step 22000: 3.022461
# Average loss at step 24000: 3.070728
# Average loss at step 26000: 3.049752
# Average loss at step 28000: 2.870786
# Average loss at step 30000: 2.978295
# Nearest to b: d, c, wreckage, r, publica, authentically, avalokitesvara, normand,
# Nearest to with: between, equine, when, freitas, rightist, renewing, criminally, pesos,
# Nearest to only: mandrakesoft, promiscuous, never, always, poorly, filter, censor, neopaganism,
# Nearest to were: are, was, have, had, became, snack, elbing, been,
# Nearest to years: months, days, decades, year, times, hours, weeks, consumers,
# Nearest to there: they, it, he, gresham, these, we, she, pokes,
# Nearest to an: waxes, dyslexic, kriegsmarine, liters, lebrun, monkees, another, neh,
# Nearest to the: their, its, his, a, cy, macho, this, dorset,
# Nearest to when: if, after, while, before, though, where, kar, with,
# Nearest to world: wilkinson, pacified, instructing, coalescence, flashes, blurred, vendors, lions,
# Nearest to war: physica, inspirational, fifa, francesca, richness, propagandist, fournier, enclave,
# Nearest to new: particular, racers, review, psalms, greek, prays, samoan, cyclops,
# Nearest to at: in, under, hessen, ultimatum, ballroom, noaa, after, leaflet,
# Nearest to which: that, this, what, who, also, it, still, usually,
# Nearest to six: eight, five, four, three, seven, nine, two, zero,
# Nearest to many: some, several, various, these, numerous, most, such, those,
# Average loss at step 32000: 2.976852
# Average loss at step 34000: 2.961329
# Average loss at step 36000: 2.953704
# Average loss at step 38000: 2.975584
# Average loss at step 40000: 2.982216
# Nearest to b: d, c, normand, avalokitesvara, fe, steinberg, matrimonial, lane,
# Nearest to with: between, renewing, equine, rightist, in, freitas, pesos, leontopithecus,
# Nearest to only: always, mandrakesoft, usually, still, promiscuous, actually, never, no,
# Nearest to were: are, have, had, was, those, been, although, be,
# Nearest to years: days, decades, months, year, weeks, times, hours, centuries,
# Nearest to there: they, it, he, we, usually, she, now, sometimes,
# Nearest to an: lebrun, dyslexic, kriegsmarine, anxieties, another, ninlil, cherbourg, elegant,
# Nearest to the: their, its, his, a, our, this, any, these,
# Nearest to when: if, before, after, while, where, although, though, during,
# Nearest to world: statisticians, instructing, wilkinson, pacified, u, madras, jadwiga, aristocrat,
# Nearest to war: physica, inspirational, fifa, fournier, richness, propagandist, abdali, warrior,
# Nearest to new: particular, racers, review, carolyn, modern, illuminated, psalms, old,
# Nearest to at: in, under, astrologers, on, gruyter, hessen, ultimatum, plumes,
# Nearest to which: that, who, this, what, usually, also, these, typically,
# Nearest to six: eight, seven, five, nine, four, zero, three, two,
# Nearest to many: some, several, various, numerous, most, these, all, those,
# Average loss at step 42000: 2.929320
# Average loss at step 44000: 2.890298
# Average loss at step 46000: 2.859246
# Average loss at step 48000: 2.915107
# Average loss at step 50000: 2.872222
# Nearest to b: d, mayhem, councillor, c, persuasion, toledo, detonating, brugha,
# Nearest to with: between, renewing, rightist, freitas, including, by, surrealism, giant,
# Nearest to only: never, usually, actually, poorly, still, always, no, obviously,
# Nearest to were: are, have, was, had, been, being, while, be,
# Nearest to years: days, decades, months, weeks, hours, year, times, minutes,
# Nearest to there: they, it, he, usually, we, gresham, believed, still,
# Nearest to an: catamaran, lebrun, another, subsumed, chiles, waxes, anxieties, perrault,
# Nearest to the: his, a, their, macho, your, any, gus, our,
# Nearest to when: if, while, before, after, though, although, where, during,
# Nearest to world: u, wilkinson, instructing, silk, pacified, warranty, visions, sizes,
# Nearest to war: hypothetically, richness, fournier, inspirational, physica, fifa, tour, abdali,
# Nearest to new: particular, psalms, review, gothenburg, modern, front, shipment, glace,
# Nearest to at: within, gruyter, in, during, under, from, finalised, scrabble,
# Nearest to which: who, that, also, usually, what, this, typically, still,
# Nearest to six: seven, four, eight, five, three, nine, zero, two,
# Nearest to many: several, some, various, numerous, all, these, few, most,
# Average loss at step 52000: 2.888628
# Average loss at step 54000: 2.764413
# Average loss at step 56000: 2.846492
# Average loss at step 58000: 2.855092
# Average loss at step 60000: 2.798406
# Nearest to b: d, brugha, c, avalokitesvara, single, rodeo, normand, scholar,
# Nearest to with: between, renewing, equine, in, vaccinations, ichthyology, by, pesos,
# Nearest to only: normally, either, dumont, always, generally, still, pyrotechnics, usually,
# Nearest to were: are, was, have, had, include, those, became, be,
# Nearest to years: days, decades, months, times, weeks, centuries, hours, minutes,
# Nearest to there: they, it, he, still, now, she, usually, sometimes,
# Nearest to an: dyslexic, ninlil, catamaran, another, blistering, fully, dioxin, lebrun,
# Nearest to the: their, its, his, dancehall, macho, these, a, your,
# Nearest to when: if, before, while, after, though, where, although, during,
# Nearest to world: instructing, warranty, u, compostela, wilkinson, terminology, weekday, european,
# Nearest to war: fifa, fournier, hypothetically, wars, elizabeth, inspirational, barely, cups,
# Nearest to new: particular, psalms, cyclops, gothenburg, carolyn, boka, front, crouching,
# Nearest to at: in, near, during, hessen, under, gorge, astrologers, from,
# Nearest to which: that, this, also, usually, what, typically, who, where,
# Nearest to six: seven, five, eight, four, nine, three, zero, two,
# Nearest to many: some, several, numerous, various, these, those, all, few,
# Average loss at step 62000: 2.769120
# Average loss at step 64000: 2.733411
# Average loss at step 66000: 2.788098
# Average loss at step 68000: 2.815713
# Average loss at step 70000: 2.655579
# Nearest to b: d, brugha, c, avalokitesvara, lithuanians, rieure, tsunamis, loophole,
# Nearest to with: between, equine, freitas, renewing, pesos, rightist, leontopithecus, surrealism,
# Nearest to only: either, binghamton, always, pyrotechnics, generally, normally, poorly, mandrakesoft,
# Nearest to were: are, have, had, those, was, been, include, be,
# Nearest to years: months, decades, days, weeks, minutes, hours, times, year,
# Nearest to there: they, it, he, we, she, marys, pokes, still,
# Nearest to an: catamaran, dyslexic, another, collides, perrault, clytemnestra, anxieties, graduation,
# Nearest to the: their, his, its, a, our, any, your, each,
# Nearest to when: if, while, before, although, though, where, after, during,
# Nearest to world: warranty, u, outlying, terminology, visions, turbofan, silk, incorporeal,
# Nearest to war: wars, fournier, physica, hypothetically, enclave, fifa, richness, elizabeth,
# Nearest to new: particular, gothenburg, psalms, different, charter, carolyn, talib, racers,
# Nearest to at: near, in, astrologers, under, gorge, on, during, ticino,
# Nearest to which: that, this, also, what, who, usually, typically, these,
# Nearest to six: seven, five, eight, four, three, nine, zero, two,
# Nearest to many: several, some, numerous, various, most, all, those, few,
# Average loss at step 72000: 2.812214
# Average loss at step 74000: 2.835680
# Average loss at step 76000: 2.803052
# Average loss at step 78000: 2.679978
# Average loss at step 80000: 2.774639
# Nearest to b: d, c, avalokitesvara, pln, l, brugha, toledo, lithuanians,
# Nearest to with: between, pesos, ichthyology, leontopithecus, intramolecular, freitas, renewing, by,
# Nearest to only: never, pyrotechnics, either, always, mandrakesoft, still, promiscuous, scepticism,
# Nearest to were: are, have, had, was, those, include, snack, remain,
# Nearest to years: months, decades, days, minutes, weeks, hours, centuries, times,
# Nearest to there: they, it, he, she, we, believed, currently, generally,
# Nearest to an: catamaran, dyslexic, waxes, anxieties, lebrun, neh, painters, kriegsmarine,
# Nearest to the: their, its, his, monosodium, our, hostels, marangella, increment,
# Nearest to when: while, if, before, although, though, where, after, during,
# Nearest to world: u, flashes, weekday, europe, warranty, compostela, antichrist, barrington,
# Nearest to war: wars, fifa, richness, fournier, hypothetically, enclave, am, physica,
# Nearest to new: particular, carolyn, racers, gothenburg, addams, sequential, waging, specific,
# Nearest to at: near, in, during, on, gorge, before, astrologers, gruyter,
# Nearest to which: that, this, typically, what, usually, also, who, actually,
# Nearest to six: eight, seven, four, five, nine, three, zero, two,
# Nearest to many: some, several, numerous, various, all, most, few, both,
# Average loss at step 82000: 2.746935
# Average loss at step 84000: 2.763804
# Average loss at step 86000: 2.754150
# Average loss at step 88000: 2.684518
# Average loss at step 90000: 2.734165
# Nearest to b: d, c, balts, avalokitesvara, brugha, pln, buick, rodeo,
# Nearest to with: between, webcomics, equine, freitas, pesos, without, surrealism, among,
# Nearest to only: either, usually, always, until, generally, convoluted, pyrotechnics, normally,
# Nearest to were: are, was, have, those, had, been, being, be,
# Nearest to years: days, decades, months, minutes, weeks, centuries, hours, year,
# Nearest to there: they, it, he, she, believed, we, sometimes, marys,
# Nearest to an: dyslexic, dioxin, the, catamaran, spaceflights, anxieties, brassiere, kriegsmarine,
# Nearest to the: its, their, any, your, a, his, hostels, our,
# Nearest to when: if, while, before, though, where, although, after, during,
# Nearest to world: u, european, voce, largest, statisticians, warranty, cernunnos, seminole,
# Nearest to war: wars, physica, fournier, hypothetically, richness, enclave, fifa, benevolent,
# Nearest to new: particular, sequential, cyclops, gothenburg, modern, adin, psalms, charter,
# Nearest to at: near, during, within, astrologers, in, on, deco, gruyter,
# Nearest to which: that, this, typically, what, also, who, usually, actually,
# Nearest to six: seven, nine, four, five, eight, three, zero, two,
# Nearest to many: several, some, numerous, various, most, few, these, those,
# Average loss at step 92000: 2.711682
# Average loss at step 94000: 2.386481
# Average loss at step 96000: 2.383509
# Average loss at step 98000: 2.607859
# Average loss at step 100000: 2.635162
# Nearest to b: d, c, lithuanians, loophole, rshavn, persuasion, tarn, rieure,
# Nearest to with: between, pesos, renewing, equine, freitas, leontopithecus, by, outreach,
# Nearest to only: always, either, generally, usually, actually, normally, pyrotechnics, motorised,
# Nearest to were: are, was, have, had, include, those, been, remain,
# Nearest to years: months, days, decades, minutes, weeks, hours, centuries, year,
# Nearest to there: it, they, believed, still, marys, now, he, sometimes,
# Nearest to an: catamaran, dyslexic, neh, kriegsmarine, perrault, stately, anxieties, livelihood,
# Nearest to the: its, their, his, this, a, libido, facilitator, wahid,
# Nearest to when: if, before, where, while, though, after, although, until,
# Nearest to world: u, warranty, visions, european, voce, flashes, statisticians, babylon,
# Nearest to war: wars, physica, fifa, dravidians, warrior, enclave, richness, francesca,
# Nearest to new: particular, single, addams, racers, sequential, gothenburg, berklee, prosperous,
# Nearest to at: near, during, astrologers, cookies, gruyter, calvinball, within, gorge,
# Nearest to which: that, what, who, this, also, typically, faire, these,
# Nearest to six: eight, seven, five, four, three, nine, zero, two,
# Nearest to many: some, several, numerous, various, those, both, most, such,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(20,20))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
